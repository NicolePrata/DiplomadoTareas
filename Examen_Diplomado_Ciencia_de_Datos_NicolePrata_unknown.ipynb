# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolePrata/DiplomadoTareas/blob/main/Examen_Diplomado_Ciencia_de_Datos_NicolePrata_unknown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DIPLOMADO CIENCIA MATEMÁTICA DE DATOS
#
# ## Examen

# %% [markdown]
# ### Examen Teórico

# %% [markdown]
# **Instrucciones**
#
# Contesta las siguientes.

# %% [markdown]
# 1. ¿Cuál es la diferencia entre Data Analysis y Data Science?

# %% [markdown]
# **R.** El análisis de datos o Data Analysis es analizar una base de datos y obtener y/o extraer su información más valiosa, limpiar sus valores más significativos o importantes y tratar de descubrir las relaciones, tendencias o conexiones entre ellos. Para mí sería como el primer análisis exploratorio.
#
# Por otro lado, la ciencia de datos o Data Science ya involucra más conceptos de estadística, probabilidad, clasificación e incluso predicción de nuestros datos.También es donde se aplican los modelos o algoritmos con IA que nos ayudan a simplificar el análisis de los datos.

# %% [markdown]
# 2. ¿Cuál es el proposito del análisis exploratorio?

# %% [markdown]
# **R.** Este análisis se le aplica a los datos con el propósito de entender mejor la base de datos, cómo se conforma, conocer el tamaño de los datos con los que estamos trabajando, su descripción; identificar si es necesario aplicar alguna limpieza o acomodo a los datos con el objetivo de poder quedarnos con la información más importante para posteriormente proponer un modelo o un análisis más a fondo para aplicarle algún algoritmo, clasificación, predicción, etc

# %% [markdown]
# 3. ¿Cuáles son los problemas más comunes que uno encuentra en el análisis de datos?

# %% [markdown]
# **R.**
#
# *   Que existan valores nulos o que no haya valores que se necesiten para el análisis.
# *   Que falte información importante que, de existir, simplificaría el análisis.
# *   Que sea una cantidad muy enorme de los datos y el procesamiento o el tiempo de cómputo se ralentice.
# *   Que haya valores raros que modifiquen o alteren el análisis de todo el sistema.

# %% [markdown]
# 4. ¿Cuáles son los pasos en un proyecto de análisis de datos?

# %% [markdown]
# **R.**
# 1. Recopilar los datos.
# 2. Visualizar los datos.
# 3. Realizar una limpieza de los datos.
# 4. Preparar los datos para poder trabajar con ellos.
# 5. Analizar los datos para definir qué problema se va a resolver o qué datos tienen relaciones interesantes para visualizar.
# 6. Visualizar los datos.
# 7. Analizar si se le puede aplicar un modelo de predicción o descripción.
# 8. Aplicar estos modelos y ver cuál se ajusta mejor a los datos.
# 9. Interpretar los resultados que se obtuvieron del análisis.

# %% [markdown]
# 5. ¿Cuáles son las diferencias en Aprendizaje Supervisado y Aprendizaje No Supervisado?

# %% [markdown]
# **R.** En el aprendizaje no supervisado se nos dan los datos y nosotros debemos encontrar relaciones interesantes entre los datos, así como grupos y patrones. Aquí podemos aplicar lo de Clustering o agrupamiento.
#
# En el aprendizaje supervisado tenemos una columna objetivo que es con la que se trabaja para que el sistema "aprenda" o para poder entrenarlo para que llegue a un resultado o salida específica. Aquí es donde se aplican los modelos de clasificación, regresión y/o predicción.

# %% [markdown]
# 6. ¿Qué es Reducción de Dimensiones y cuáles son sus beneficios?

# %% [markdown]
# **R.** Es la técnica que se utiliza para reducir el número de dimensiones, variables o información en una base de datos.
#
# Los beneficios son:
# *   Ahorro de tiempo de cómputo o recursos.
# *   Mejor visualización de los datos.
# *   Eliminar el análisis de datos que son irrelevantes.

# %% [markdown]
# 7. ¿Qué son los sistemas de recomendación?
#
# ---

# %% [markdown]
# **R.** Son modelos o algoritmos que se basan en una base de datos donde vienen ciertas preferencias del usuario y basado en eso, recomiendan o sugieren cosas similares.

# %% [markdown]
# 8. ¿Qué es clustering y para qué sirve en la ciencia de datos?

# %% [markdown]
# **R.** El clustering o agrupamiento en la ciencia de datos es agrupar los datos que tienen características similares o que son similares entre ellos.
#
# Sirve para explorar mejor los datos y ver cómo están distribuidos; también para dar alguna recomendación en base a alguna preferencia en específico, analizar imágenes o reconocer imágenes en base a otras que se parezcan, detectar algún dato diferente o anómalo en un conjunto de datos (como para evitar algún tipo de fraude)

# %% [markdown]
# 9. ¿Cómo puedo elegir el mejor valor de K para K-Means?

# %% [markdown]
# **R.** Hay dos modelos que se nos enseñaron en clase para poder elegir un buen valor, está el método Silhouette o el método del codo
#
#
#
# 1.   Método Silhouette.
# Es una métrica que mide la calidad de la agrupación mediante ver qué tan compactos y separados son entre ellos. Aquí el valor de k varía de -1 a 1, donde una puntuación más alta indica una mejor agrupación, mientras que los valores más cercanos a 1 indican agrupaciones densas y bien separadas.
#
# 2.   Método del codo.
# El método del codo ayuda a determinar el número óptimo de clusterings mediante la evaluación de la suma de cuadrados dentro del clúster para diferentes valores de K. Un cluster que tiene una suma pequeña de cuadrados es más compacto que un cluster que tiene una suma grande de cuadrados.

# %% [markdown]
# 10. ¿Cuál es la diferencia entre los modelos de clasificación y los modelos de regresión?

# %% [markdown]
# **R.** Los métodos de clasificación se utilizan para valores categóricos, es decir que pertenecen a categorías. Un modelo de clasificación arroja valores como accuracy, precisión, recall, f1-score, entre otros.
#
# Los métodos de regresión se utilizan para variables numéricas y predicen un valor númerico o alguna cantidad. Estos arrojan valores como error cuadrático medio.

# %% [markdown]
# 11. Menciona dos métricas de evaluación para los modelos de regresión y cómo se interpretan.

# %% [markdown]
# **R.**
# *   Error Cuadrático Medio
#
# MSE mide la diferencia cuadrática promedio entre los valores que se predijeron y los valores reales de la variable objetivo.
# Los valores de MSE más bajos indican un mejor rendimiento del modelo, ya que indican que las predicciones del modelo están más cerca de los valores reales.
#
#
#
# *   R^2 Score
#
# La puntuación R^2 es la proporción de la varianza en la variable objetivo que el modelo puede explicar.
# La puntuación R^2 oscila entre 0 y 1, donde 1 indica un ajuste perfecto y 0 indica que el modelo no explica ninguna varianza en la variable objetivo.

# %% [markdown]
# 12. ¿Qué es una matriz de confusión? ¿Cuáles métricas de evaluación podemos calcular con ella?

# %% [markdown]
# **R.** Una matriz de confusión es una matriz que evalúa el modelo de predicción que se utilizó y lo compara con los valores reales.
# Tiene por lo general cuatro cuadros: donde aparece verdadero positivo, falso-positivo, verdadero negativo y falso-negativo.
# Lo que se puede calcular es:
# 1.   Accuracy o precisión
# 2.   Precisión
# 3.   Recall
# 4.   F1-Score

# %% [markdown]
# 13. Menciona las diferencias entre "correlación" y "causalidad".

# %% [markdown]
# **R.**

# %% [markdown]
# 14. ¿Qué es Deep Learning?

# %% [markdown]
# **R.** Es en español Aprendizaje Profundo y es aquel que entrena modelos de IA extrayendo patrones y características de la base de datos para poder reconocer patrones y clasificar o predecir ciertos valores o comportamiento del modelo.

# %% [markdown]
# 15. ¿Qué es un perceptrón?

# %% [markdown]
# **R.** Un perceptrón es un algoritmo o una función que toma un conjunto de datos como entrada y las transforma en una salida, que es la predicción que hace el modelo.

# %% [markdown]
# 16. ¿Qué es el procesamiento de lenguaje natural (NLP) y cómo se aplica en ciencia de datos?

# %% [markdown]
# **R.** El NLP se encarga de procesar el lenguaje de los seres humanos para que haya una interacción entre ellos y las computadores mediante el lenguaje. Se aplica en ciencia de datos para extraer información importante de textos, analizarla y procesarla; clasifica los datos o palabras y los extrae para analizar palabras relevantes para el entendimiento de los textos.

# %% [markdown]
# 17. ¿Cuál es el mejor modelo de clasificación para NLP y por qué?

# %% [markdown]
# **R.** De los modelos de clasificación para NLP que vimos en clase serían
#
# *   Suport Vector Machine (SVM) que
# *   Naive Bayes
# *   Random Forest
# *   Decision Trees

# %% [markdown]
# 18. Menciona 3 casos de usos para Machine Learning.

# %% [markdown]
# **R.**
# 1. Recomendaciones para gustos en específico, como elegir una película o serie en Netflix.
# 2. Asistentes virtuales como Siri, Alexa.
# 3. Predicción o diagnóstico de enfermedades.

# %% [markdown]
# 19. Menciona 2 modelos de predicción y describe brevemente cómo funcionan.

# %% [markdown]
# **R.**
# 1. Regresión Logística
#
# La regresión logística es utilizada para problemas de clasificación binaria, donde se busca predecir si un valor pertenece a una de dos categorías mutuamente excluyentes (por ejemplo, "sí" o "no", "positivo" o "negativo"). La función logística asigna las características de entrada y sus coeficientes a un valor entre 0 y 1, representando la probabilidad de que pertenezca a la clase positiva. Durante el entrenamiento se optimizan los coeficientes para maximizar la probabilidad de los datos observados dadas las probabilidades predichas.
#
# 2. Random Forest
#
# Random Forest es un método de aprendizaje conjunto que combina múltiples árboles de decisión para hacer predicciones.
# Durante el entrenamiento, cada árbol se entrena con un subconjunto aleatorio de datos de entrenamiento y un subconjunto aleatorio de características.
# Durante la predicción, cada árbol vota por la etiqueta de clase y el voto mayoritario determina la predicción final.

# %% [markdown]
# 20. Menciona 2 modelos de clasificación y describe brevemente cómo funcionan.

# %% [markdown]
# **R.**

# %% [markdown]
# ### Examen Práctico

# %% [markdown]
# **Instrucciones**
# Escoge uno de los siguientes datasets, descárgalo, define un problema a resolver y utilízalo para aplicar el modelo de Data Science que mejor creas.
# * *Bike Sharing Dataset:* https://archive.ics.uci.edu/dataset/275/bike+sharing+dataset
# * *Stock Market Dataset:* https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset
# * *Titanic Dataset:* https://www.kaggle.com/c/titanic/data
# * *Spam Email Dataset:* https://archive.ics.uci.edu/dataset/94/spambase
# * *Book-Crossing Dataset:* https://www.kaggle.com/datasets/somnambwl/bookcrossing-dataset
# * *Twitter Dataset:* https://www.kaggle.com/datasets/jp797498e/twitter-entity-sentiment-analysis

# %% [markdown]
# #### **Explicación del problema**

# %% [markdown]
# **R.** El problema que elegí o lo que le realizaré a esta base de datos es:
# 1. Checar de qué temas se habla más en Twitter
# 2. Hacer una limpieza de los comentarios
# 3. Hacer un gráfico donde muestro las palabras que son más utilizadas
# 4. Hacer otra limpieza para seleccionar analizar mejor los comentarios y realizar otro análisis de cuáles son las palabras más utilizadas.
# 5. Hacer una gráfica con los porcentajes de los sentimientos.

# %% [markdown]
# #### **Código**

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %%
#cargamos librerias
import pandas as pd
import numpy as np
import plotly.express as px
import random
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.corpus import stopwords
import re, string
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import plotly.express as px
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('/content/twitter_training2.csv')
train.head()
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
test=pd.read_csv('/content/twitter_validation.csv')
test.head()
# Out:
#    3364   Facebook Irrelevant  \
# 0   352     Amazon    Neutral
# 1  8312  Microsoft   Negative
# 2  4371      CS-GO   Negative
# 3  4433     Google    Neutral
# 4  6273       FIFA   Negative
#
#   I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣
# 0  BBC News - Amazon boss Jeff Bezos rejects clai...
# 1  @Microsoft Why do I pay for WORD when it funct...
# 2  CSGO matchmaking is so full of closet hacking,...
# 3  Now the President is slapping Americans in the...
# 4  Hi @EAHelp I’ve had Madeleine McCann in my cel...

# %% [markdown]
# Análisis Exploratorio

# %%
test.columns=['coment', 'about', 'sentiment', 'content']
test
# Out:
#      coment                about   sentiment  \
# 0       352               Amazon     Neutral
# 1      8312            Microsoft    Negative
# 2      4371                CS-GO    Negative
# 3      4433               Google     Neutral
# 4      6273                 FIFA    Negative
# ..      ...                  ...         ...
# 994    4891  GrandTheftAuto(GTA)  Irrelevant
# 995    4359                CS-GO  Irrelevant
# 996    2652          Borderlands    Positive
# 997    8069            Microsoft    Positive
# 998    6960      johnson&johnson     Neutral
#
#                                                content
# 0    BBC News - Amazon boss Jeff Bezos rejects clai...
# 1    @Microsoft Why do I pay for WORD when it funct...
# 2    CSGO matchmaking is so full of closet hacking,...
# 3    Now the President is slapping Americans in the...
# 4    Hi @EAHelp I’ve had Madeleine McCann in my cel...
# ..                                                 ...
# ...

# %%
train.columns=['coment', 'about', 'sentiment', 'content']
train
# Out:
#        coment        about sentiment  \
# 0        2401  Borderlands  Positive
# 1        2401  Borderlands  Positive
# 2        2401  Borderlands  Positive
# 3        2401  Borderlands  Positive
# 4        2401  Borderlands  Positive
# ...       ...          ...       ...
# 74676    9200       Nvidia  Positive
# 74677    9200       Nvidia  Positive
# 74678    9200       Nvidia  Positive
# 74679    9200       Nvidia  Positive
# 74680    9200       Nvidia  Positive
#
#                                                  content
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# ...

# %%
train.shape
# Out:
# (74681, 4)

# %%
test.shape
# Out:
# (999, 4)

# %%
df_freq = pd.DataFrame(train['about'].value_counts()).reset_index()
df_freq.columns = ['Tema', 'freq']

fig = px.bar(df_freq, x = "Tema", y = "freq", color = "Tema", text = "freq", title = "Twitter Posts", template = 'plotly_white')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
comments = []
for comment in train["content"]:
    comments.append(list(word_tokenize(str(comment).lower())))
comments[0]
# Out:
# ['i',
#  'am',
#  'coming',
#  'to',
#  'the',
#  'borders',
#  'and',
#  'i',
#  'will',
#  'kill',
#  'you',
#  'all',
#  ',']

# %%
def get_all_words(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

# %%
all_words = list(get_all_words(list(comments)))

# %%
WF = nltk.FreqDist(all_words)
WFdf = pd.DataFrame(WF.most_common(30))
WFdf.columns = ['Word', "Frequency"]
fig = px.bar(WFdf, x = "Frequency", y = "Word", orientation='h', text = "Frequency", width=1000, height=750, template = 'plotly_white',
             title = 'Word Count - 1')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
comment_words = ''
comment_words += " ".join(all_words)+" "
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(comment_words)

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
#voy a limpiar los datos
def remove_noise(comment, stop_words = ()):
    lemmatizer = WordNetLemmatizer()
    cleaned_tokens = []
    for token, tag in pos_tag(comment):
        token = re.sub(r'\W', ' ', token)
        token = re.sub(r'\s+[a-zA-Z]\s+', ' ', token)
        token = re.sub(r'\^[a-zA-Z]\s+', ' ', token)
        token = re.sub(r'\s+', ' ', token, flags=re.I)
        token = re.sub(r'^b\s+', '', token)
        token = re.sub(' +', ' ', token)
        if token == 'n t':
          token = 'not'
        if token == ' s':
          token = 'is'
        if token == 've':
          token = 'have'
        if token == 'ca':
          token = 'can'
        if token == 'wo':
          token = 'will'
        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        token = lemmatizer.lemmatize(token, pos = pos)
        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

# %%
stop_words = set(stopwords.words('english'))
stop_words.update([' '])

# %%
comments = []
for comment in train["content"]:
    comments.append(word_tokenize(str(comment).lower()))
comments[0]
# Out:
# ['i',
#  'am',
#  'coming',
#  'to',
#  'the',
#  'borders',
#  'and',
#  'i',
#  'will',
#  'kill',
#  'you',
#  'all',
#  ',']

# %%
clean_comments = []
for comment in comments:
    clean_comments.append(remove_noise(comment, stop_words))
clean_comments[0]
# Out:
# ['come', 'border', 'kill']

# %%
all_words = list(get_all_words(list(clean_comments)))

# %%
WF = nltk.FreqDist(all_words)
WFdf = pd.DataFrame(WF.most_common(30))
WFdf.columns = ['Word', "Frequency"]
fig = px.bar(WFdf, x = "Frequency", y = "Word", orientation='h', text = "Frequency", width=1000, height=750, template = 'plotly_white',
             title = 'Word Count - 1')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
comment_words = ''
comment_words += " ".join(all_words)+" "
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(comment_words)

plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
#porcentaje de sentimientos encontrados
df_sentiment = train.sentiment.value_counts().reset_index()
df_sentiment.columns = ['Sentiment', 'Count']
fig = px.pie(df_sentiment, values = 'Count', names = 'Sentiment', title = 'Sentiment Percentage')
fig.update_traces(textposition = 'inside', textinfo = 'percent+label')
fig.update_layout(showlegend = False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_sen = (train.groupby(['about']).sentiment.value_counts(normalize = True)*100).reset_index()
df_sen.columns = ['about', 'sentiment', 'Percentage']
fig = px.bar(df_sen, x = 'about', y = 'Percentage', color = 'sentiment', title = 'Sentimientos por Tema',
             text = df_sen['Percentage'].apply(lambda x: '{0:1.2f}%'.format(x)),
             color_discrete_map = {'Positive':'#00CC96', 'Neutral':'#636EFA', 'Negative':'#EF553B'}, template = 'plotly_white')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### **Explicación de resultados**

# %% [markdown]
# **R.**
# 1. De lo que más se habla en Twitter es de Microsoft, MaddenNFL y League of Legends, entre otros.
#
# 2. La palabra más utilizada es Game.
#
# 3. En general, hay más comentarios negativos que de otro tipo.
