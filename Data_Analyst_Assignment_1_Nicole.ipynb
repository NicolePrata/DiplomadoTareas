# %% [markdown]
# <a href="https://colab.research.google.com/github/NicolePrata/DiplomadoTareas/blob/main/Data_Analyst_Assignment_1_Nicole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Analyst Assignment

# %% [markdown]
# ## Introduction
#
# You are working with a US retail customer on a pilot deployment.  They are using technology to track their merchandise throughout their supply chain.  The flow of their supply is:
#
# *   **DC 1:**  Orders are filled and palletized.
# *   **Truck:** Pallets travel from the DC 1 to DC 2 via semi-truck.
# *   **DC 2:**  Pallets are unloaded, and additional merchandise may be added.  They are then reloaded onto a new truck.
# *   **Truck:** Pallets travel from DC 2 to the Store.
# *   **Store:** Pallets are unloaded, cases are removed, and stocked, and the empty cases are left behind the building awaiting pickup.
#
# Your job is to dig into the data and find compelling insights to show the value fo the technology and help move the contract from a pilot into a full scaled deployment.
#
#
#
# ---

# %% [markdown]
# ## Part 0: Imports
#
# Import necessary packages and

# %%
# YOUR CODE HERE:
import pandas as pd
import numpy as np

datos = pd.read_excel('/content/Assignment_1.xlsx')

# %% [markdown]
# ### Dataset Overview
#
# * Site:  A large space that could contain multiple readers. Ex: DC 1.
# * Zone:  Point of interest. These represent areas in which repeaters are installed. These can be thought of as sub-zones.  Ex: Dock Doors.
# * Asset ID: The unique ID of the asset.
# * Asset Type: The type of thing that is detected (ie tote).
# * Device ID: The unique gateway reader ID that detected the device in the zone (there can be multiple in one zone).
# * Time est: The time in EST.
# * Lon: Longituge
# * Lat: Latitude
# * Temperature_C / F: Temperature in Celsius, Fahrentheit

# %% [markdown]
# ## PART 1: Data Overview

# %% [markdown]
# ### Question 1:
#
# * How many unique cases were we tracking throughout this pilot. (1 pt)
# * What are the unique zones we could see (1 pt)
# * How many POI's are in each Zone. (2 pts)

# %%
# YOUR CODE HERE:



print('Los casos unicos de caja son')
datos.asset_id.nunique()
# Out:
# Los casos unicos de caja son
# 18

# %%
datos.asset_id.unique()
# Out:
# array([  2,  37,  52,  58,  59,  62,  70,  84, 102, 145, 149, 159, 167,
#        170, 181, 182, 200, 205])

# %%
datos.Zone.unique()
# Out:
# array(['dock_doors_DC1', 'dock_doors_DC2', 'Forklift3_DC1',
#        'pallet_assembly_DC1', 'PhoneKit1Bridge', 'PhoneKit2Bridge',
#        'PhoneKit2GW', 'point_of_sale_Store', 'receiving_Store',
#        'staging_DC1', 'staging_DC2', 'store_back_Store',
#        'store_front_Store', 'Forklift1_DC1', 'PhoneKit1GW'], dtype=object)

# %%
datos
# Out:
#        asset_type  asset_id                           tag_id   Site  \
# 0            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4            tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...           ...       ...                              ...    ...
# 130056       tote       205  (01)00850027865010(21)0082T1137  Store
# 130057       tote       205  (01)00850027865010(21)0082T1137  Store
# 130058       tote       205  (01)00850027865010(21)0082T1137  Store
# 130059       tote       205  (01)00850027865010(21)0082T1137  Store
# 130060       tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zone     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# 1          dock_doors_DC1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158
# 2          dock_doors_DC1  7F9A8353E973 2022-08-02 12:01:11.234  47.79158
# 3          dock_doors_DC1  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158
# 4          dock_doors_DC1  7F9A8353E973 2022-08-02 11:58:55.049  47.79158
# ...                   ...           ...                     ...       ...
# 130056  store_front_Store  26AB1C9A2E41 2022-08-04 12:48:51.273  47.74923
# 130057  store_front_Store  26AB1C9A2E41 2022-08-04 12:49:58.699  47.74923
# 130058  store_front_Store  26AB1C9A2E41 2022-08-04 12:52:45.173  47.74923
# 130059  store_front_Store  26AB1C9A2E41 2022-08-04 12:53:48.228  47.74923
# 130060  store_front_Store  26AB1C9A2E41 2022-08-04 16:33:25.525  47.74923
#
#              lng  Temperature_C  Temperature_F
# 0      -65.68902           23.0          73.40
# 1      -65.68902           23.0          73.40
# 2      -65.68902           23.0          73.40
# 3      -65.68902           23.5          74.30
# 4      -65.68902           23.0          73.40
# ...          ...            ...            ...
# 130056 -65.64101           23.1          73.58
# 130057 -65.64101           23.5          74.30
# 130058 -65.64101           23.0          73.40
# 130059 -65.64101           23.0          73.40
# 130060 -65.64101           24.0          75.20
#
# [130061 rows x 11 columns]

# %%
datos['Zone_POI']=datos.Zone.str.split('_').str[:2]
datos
# Out:
#        asset_type  asset_id                           tag_id   Site  \
# 0            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 1            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 2            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 3            tote         2  (01)00850027865010(21)0082T0219   DC 1
# 4            tote         2  (01)00850027865010(21)0082T0670   DC 1
# ...           ...       ...                              ...    ...
# 130056       tote       205  (01)00850027865010(21)0082T1137  Store
# 130057       tote       205  (01)00850027865010(21)0082T1137  Store
# 130058       tote       205  (01)00850027865010(21)0082T1137  Store
# 130059       tote       205  (01)00850027865010(21)0082T1137  Store
# 130060       tote       205  (01)00850027865010(21)0082T1137  Store
#
#                      Zone     device_id                time_est       lat  \
# 0          dock_doors_DC1  7F9A8353E973 2022-08-02 11:59:26.628  47.79158
# 1          dock_doors_DC1  EC5B0499234F 2022-08-02 12:00:22.660  47.79158
# 2          dock_doors_DC1  7F9A8353E973 2022-08-02 12:01:11.234  47.79158
# 3          dock_doors_DC1  3D8B2BDB8673 2022-08-02 13:47:58.172  47.79158
# 4          dock_doors_DC1  7F9A8353E973 2022-08-02 11:58:55.049  47.79158
# ...                   ...           ...                     ...       ...
# 130056  store_front_Store  26AB1C9A2E41 2022-08-04 12:48:51.273  47.74923
# 130057  store_front_Store  26AB1C9A2E41 2022-08-04 12:49:58.699  47.74923
# 130058  store_front_Store  26AB1C9A2E41 2022-08-04 12:52:45.173  47.74923
# 130059  store_front_Store  26AB1C9A2E41 2022-08-04 12:53:48.228  47.74923
# 130060  store_front_Store  26AB1C9A2E41 2022-08-04 16:33:25.525  47.74923
#
#              lng  Temperature_C  Temperature_F        Zone_POI
# 0      -65.68902           23.0          73.40   [dock, doors]
# 1      -65.68902           23.0          73.40   [dock, doors]
# 2      -65.68902           23.0          73.40   [dock, doors]
# 3      -65.68902           23.5          74.30   [dock, doors]
# 4      -65.68902           23.0          73.40   [dock, doors]
# ...          ...            ...            ...             ...
# 130056 -65.64101           23.1          73.58  [store, front]
# 130057 -65.64101           23.5          74.30  [store, front]
# 130058 -65.64101           23.0          73.40  [store, front]
# 130059 -65.64101           23.0          73.40  [store, front]
# 130060 -65.64101           24.0          75.20  [store, front]
#
# [130061 rows x 12 columns]

# %%
datos[['asset_id','Site', 'Zone_POI']]
# Out:
#         asset_id   Site        Zone_POI
# 0              2   DC 1   [dock, doors]
# 1              2   DC 1   [dock, doors]
# 2              2   DC 1   [dock, doors]
# 3              2   DC 1   [dock, doors]
# 4              2   DC 1   [dock, doors]
# ...          ...    ...             ...
# 130056       205  Store  [store, front]
# 130057       205  Store  [store, front]
# 130058       205  Store  [store, front]
# 130059       205  Store  [store, front]
# 130060       205  Store  [store, front]
#
# [130061 rows x 3 columns]

# %% [markdown]
# ### Question 2:
#
# * What is the temperature range we see?  (1pt)
# * Where is temperature the highest and lowest (1pt)

# %%
# YOUR CODE HERE:
datos.groupby(['asset_id']).Temperature_C.agg(['min','max'])
# Out:
#             min    max
# asset_id
# 2         20.50  31.00
# 37        22.00  33.00
# 52        22.50  33.50
# 58        22.50  29.50
# 59        22.00  33.50
# 62        22.00  39.50
# 70        22.00  44.00
# 84        22.50  31.00
# 102       22.00  33.50
# 145       22.50  30.00
# 149       19.50  34.00
# 159       19.00  28.50
# 167       22.50  43.50
# 170       22.00  30.58
# 181       23.00  37.00
# 182       20.25  35.00
# 200       22.00  41.50
# 205       20.50  33.50

# %%
temperaturas=datos['Temperature_C']
temperaturas
# Out:
# 0         23.0
# 1         23.0
# 2         23.0
# 3         23.5
# 4         23.0
#           ...
# 130056    23.1
# 130057    23.5
# 130058    23.0
# 130059    23.0
# 130060    24.0
# Name: Temperature_C, Length: 130061, dtype: float64

# %%
tempmin=datos.Temperature_C.min()
tempmax=datos.Temperature_C.max()
rango_temp=tempmax-tempmin

print(f"Temperature Range is: {rango_temp}")
# Out:
# Temperature Range is: 25.0

# %%
print(f"The highest temperature is: {tempmax}")
print(f"The lowest temperature is: {tempmin}")
# Out:
# The highest temperature is: 44.0
# The lowest temperature is: 19.0

# %% [markdown]
# ## Part 2: The Journey of a Case

# %% [markdown]
# ### Question 3:
#
# * Create a visualization that shows where a case was at over time at the zone or POI level. Imagine that this would be included in your presentation to the customer. (Non techical audience) (3 pts)

# %%
# YOUR CODE HERE:
#datos.Site=
#datos[['asset_id','Zone', 'Zone_POI']]
data = datos[[('asset_id'),'Site', 'Zone_POI']]
data
# Out:
#         asset_id   Site        Zone_POI
# 0              2   DC 1   [dock, doors]
# 1              2   DC 1   [dock, doors]
# 2              2   DC 1   [dock, doors]
# 3              2   DC 1   [dock, doors]
# 4              2   DC 1   [dock, doors]
# ...          ...    ...             ...
# 130056       205  Store  [store, front]
# 130057       205  Store  [store, front]
# 130058       205  Store  [store, front]
# 130059       205  Store  [store, front]
# 130060       205  Store  [store, front]
#
# [130061 rows x 3 columns]

# %%
#pd.DataFrame.datos.groupby['asset_id','Site','Zone']
#pd.DataFrame(datos.groupby(['asset_id','Site','Zone']).asset_id.2())
df=pd.DataFrame(data)
df['asset_id']==2
df['Zone_POI']=data.Zone_POI.replace(',')
df
# Out:
#        asset_id   Site        Zone_POI
# 0             2   DC 1   [dock, doors]
# 1             2   DC 1   [dock, doors]
# 2             2   DC 1   [dock, doors]
# 3             2   DC 1   [dock, doors]
# 4             2   DC 1   [dock, doors]
# ...         ...    ...             ...
# 130056      205  Store  [store, front]
# 130057      205  Store  [store, front]
# 130058      205  Store  [store, front]
# 130059      205  Store  [store, front]
# 130060      205  Store  [store, front]
#
# [130061 rows x 3 columns]

# %%
import plotly.express as px
df['asset_id']=df.asset_id.astype(str)
fig = px.line(data, x='Site', y='Zone_POI', color='asset_id', markers= True, height = 800, width=1000)
#fig.update_layout(yaxis_title= 'Trabajos Remotos', xaxis_title='Año',title_text= format_title('Grafica de Lineas', 'Clase Diplomado'),template = 'plotly_white')
fig
import matplotlib.pyplot as plt

# %% [markdown]
# ### Question 4:
#
# * Visualize how the temperatue changes over time along its journey.  Imagine that this would be included in your presentation to the customer. (Non techical audience) (4 pts)

# %%
# YOUR CODE HERE:
df3=datos[['asset_id','Site','Zone_POI','Temperature_C']]
df3

# %%
for asset

# %% [markdown]
# ### Question 5:
# * Visualize the lon lat data on a map to show how the case traveled.  You may incorporate any other additional information to make this more impactful. Imagine that this would be included in your presentation to the customer. (Non techical audience) (5 pts)
#
# **Do not worry if this looks like non-sense on a map.  Ex:  The trip may appear to occur over water or in a forest because this is a toy dataset.**

# %%
# YOUR CODE HERE:

df4=datos[['asset_id','Site','Zone_POI','lat','lng']]
df4
# Out:
#         asset_id   Site        Zone_POI       lat       lng
# 0              2   DC 1   [dock, doors]  47.79158 -65.68902
# 1              2   DC 1   [dock, doors]  47.79158 -65.68902
# 2              2   DC 1   [dock, doors]  47.79158 -65.68902
# 3              2   DC 1   [dock, doors]  47.79158 -65.68902
# 4              2   DC 1   [dock, doors]  47.79158 -65.68902
# ...          ...    ...             ...       ...       ...
# 130056       205  Store  [store, front]  47.74923 -65.64101
# 130057       205  Store  [store, front]  47.74923 -65.64101
# 130058       205  Store  [store, front]  47.74923 -65.64101
# 130059       205  Store  [store, front]  47.74923 -65.64101
# 130060       205  Store  [store, front]  47.74923 -65.64101
#
# [130061 rows x 5 columns]

# %% [markdown]
# # Part 3: Customer Questions

# %% [markdown]
# ### Question 6:
#
# The customer wants to understand the efficieny of ther DC operations.
# * Based on what you see in the data, (all zones except for STORE), which parts of their operation are most & least "efficient? (10 pts)

# %%
# YOUR CODE HERE
df5=datos[['asset_id','Site','Zone_POI','time_est']]
df5
# Out:
#         asset_id   Site        Zone_POI                time_est
# 0              2   DC 1   [dock, doors] 2022-08-02 11:59:26.628
# 1              2   DC 1   [dock, doors] 2022-08-02 12:00:22.660
# 2              2   DC 1   [dock, doors] 2022-08-02 12:01:11.234
# 3              2   DC 1   [dock, doors] 2022-08-02 13:47:58.172
# 4              2   DC 1   [dock, doors] 2022-08-02 11:58:55.049
# ...          ...    ...             ...                     ...
# 130056       205  Store  [store, front] 2022-08-04 12:48:51.273
# 130057       205  Store  [store, front] 2022-08-04 12:49:58.699
# 130058       205  Store  [store, front] 2022-08-04 12:52:45.173
# 130059       205  Store  [store, front] 2022-08-04 12:53:48.228
# 130060       205  Store  [store, front] 2022-08-04 16:33:25.525
#
# [130061 rows x 4 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-d1f039bd4255> in <cell line: 1>()
# ----> 1 df6['Site']=datos.Site.drop('Store')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5235         dtype: float64
#    5236         """
# -> 5237         return super().drop(
#    5238             labels=labels,
#    5239             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['Store'] not found in axis"

# %% [markdown]
# YOUR TEXT ANSWER HERE

# %% [markdown]
# ### Question 7:
#
# The customer wants to understand the stocking efficiency in stores.
# * Based on what you see in the data, how quickly did the store unload and stock the merchandise. (5 pts)
# * How could this be converted in a KPI that a regional manager could track?  (5 pts)

# %%
# YOUR CODE HERE

# %% [markdown]
# YOUR TEXT ANSWER HERE

# %% [markdown]
# ### Question 8:
#
# Please explain what you would ask for and what you will do with this data, given that you can talk with the following people (no code needed):

# %% [markdown]
# YOUR TEXT ANSWER HERE
# * a. X How much does the temperature vary depending on where you are?
# How would they make the work of moving it more efficient so that the temperature remained more constant?
# * b. Y How much does the temperature vary depending on where you are?
# How would they make the work of moving it more efficient so that the temperature remained more constant?

# %% [markdown]
# ## Part 4: Bonus Insights

# %% [markdown]
# ### Question 8
#
# The customer is open to hearing about additional insights you found in the data above and beyond what they asked for.
# * Based on what you can see in the data, are there any other interesting insights that the customer may want to hear about? (Up to 15 bonus points)

# %%
# YOUR CODE HERE
# Another metrics that could be interesting would be temperature by time
df6=datos[['asset_id','Site','Zone_POI','Temperature_C','time_est']]
df6
# Out:
#         asset_id   Site        Zone_POI  Temperature_C                time_est
# 0              2   DC 1   [dock, doors]           23.0 2022-08-02 11:59:26.628
# 1              2   DC 1   [dock, doors]           23.0 2022-08-02 12:00:22.660
# 2              2   DC 1   [dock, doors]           23.0 2022-08-02 12:01:11.234
# 3              2   DC 1   [dock, doors]           23.5 2022-08-02 13:47:58.172
# 4              2   DC 1   [dock, doors]           23.0 2022-08-02 11:58:55.049
# ...          ...    ...             ...            ...                     ...
# 130056       205  Store  [store, front]           23.1 2022-08-04 12:48:51.273
# 130057       205  Store  [store, front]           23.5 2022-08-04 12:49:58.699
# 130058       205  Store  [store, front]           23.0 2022-08-04 12:52:45.173
# 130059       205  Store  [store, front]           23.0 2022-08-04 12:53:48.228
# 130060       205  Store  [store, front]           24.0 2022-08-04 16:33:25.525
#
# [130061 rows x 5 columns]

# %%
df6[datos.asset_id == '2']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-d12a5e34347d> in <cell line: 1>()
# ----> 1 df6[datos.asset_id == '2']
#
# TypeError: list indices must be integers or slices, not Series

# %% [markdown]
# YOUR TEXT ANSWER HERE
